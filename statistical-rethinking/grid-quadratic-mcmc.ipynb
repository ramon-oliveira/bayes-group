# %%
from tqdm import trange
import numpy as np
import scipy.stats
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="beab63c4-714e-47c8-b99b-5e61d41f4c2b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Grid approximation

# %%
n_points = 20

p_grid = np.linspace(0, 1, n_points)

prior = np.ones(n_points)

likelihood = np.array([scipy.stats.binom_test(6, 9, p) for p in p_grid])

posterior = likelihood * prior

posterior = posterior / np.sum(posterior)

p = figure(title='grid approximation - uniform prior', plot_width=400, plot_height=300)
p.line(p_grid, posterior)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7938726c-1ac8-44e4-8380-60177c872f03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7938726c-1ac8-44e4-8380-60177c872f03").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7938726c-1ac8-44e4-8380-60177c872f03");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7938726c-1ac8-44e4-8380-60177c872f03' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d4f32ad2-ec8a-46b7-93d7-43367f0f049d":{"roots":{"references":[{"attributes":{"plot":null,"text":"grid approximation - uniform prior"},"id":"da9403b4-f26f-4ab3-b6c8-612cdaab4f28","type":"Title"},{"attributes":{"callback":null},"id":"7339c2b5-383c-4375-8867-c02402ac97e5","type":"DataRange1d"},{"attributes":{},"id":"58b4b63a-7ba8-44ef-a756-574887a80fbb","type":"ToolEvents"},{"attributes":{"below":[{"id":"af936623-c2f0-4a27-b6ae-e24a806aa270","type":"LinearAxis"}],"left":[{"id":"a580bc02-244c-41d5-bb90-80f7f454a3cc","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"af936623-c2f0-4a27-b6ae-e24a806aa270","type":"LinearAxis"},{"id":"4ad4a4fe-1c45-46ba-8d98-588700178c55","type":"Grid"},{"id":"a580bc02-244c-41d5-bb90-80f7f454a3cc","type":"LinearAxis"},{"id":"ed84778b-9d36-4845-88ad-dee2961bb5fd","type":"Grid"},{"id":"c1525b32-a421-4428-9e1f-479cb8d5e040","type":"BoxAnnotation"},{"id":"ac6287fe-5c28-4461-8d38-9f36ab9f7484","type":"GlyphRenderer"}],"title":{"id":"da9403b4-f26f-4ab3-b6c8-612cdaab4f28","type":"Title"},"tool_events":{"id":"58b4b63a-7ba8-44ef-a756-574887a80fbb","type":"ToolEvents"},"toolbar":{"id":"5e50c11b-4ba9-4019-b357-d59bf62cb23c","type":"Toolbar"},"x_range":{"id":"7339c2b5-383c-4375-8867-c02402ac97e5","type":"DataRange1d"},"y_range":{"id":"a7935d43-5ad4-4c5c-a2b7-9fa37c411ab4","type":"DataRange1d"}},"id":"31772646-56e5-4e1c-a80c-9b2762c35a84","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b6ea6877-c5cd-40ee-916e-d73d232168a9","type":"PanTool"},{"id":"be6314ef-78ff-4122-ace6-3380a739f97a","type":"WheelZoomTool"},{"id":"1a7e406f-c5aa-4226-aa7e-13c31d8f8024","type":"BoxZoomTool"},{"id":"e197de3c-ecb4-41bb-bdae-273aaccc9a37","type":"SaveTool"},{"id":"1040e58f-3c89-4be9-85ad-f282480e38de","type":"ResetTool"},{"id":"df2998f7-3dfa-476f-b082-34a00e13c3ca","type":"HelpTool"}]},"id":"5e50c11b-4ba9-4019-b357-d59bf62cb23c","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9777894-82fe-4267-a403-38ff3330ddf4","type":"Line"},{"attributes":{"formatter":{"id":"9e6e648b-4769-4f02-bf6e-c00223ce2459","type":"BasicTickFormatter"},"plot":{"id":"31772646-56e5-4e1c-a80c-9b2762c35a84","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d2bfc65-8b6e-4e29-87d6-44a281c9d65a","type":"BasicTicker"}},"id":"af936623-c2f0-4a27-b6ae-e24a806aa270","type":"LinearAxis"},{"attributes":{"callback":null},"id":"a7935d43-5ad4-4c5c-a2b7-9fa37c411ab4","type":"DataRange1d"},{"attributes":{},"id":"1d2bfc65-8b6e-4e29-87d6-44a281c9d65a","type":"BasicTicker"},{"attributes":{"plot":{"id":"31772646-56e5-4e1c-a80c-9b2762c35a84","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d2bfc65-8b6e-4e29-87d6-44a281c9d65a","type":"BasicTicker"}},"id":"4ad4a4fe-1c45-46ba-8d98-588700178c55","type":"Grid"},{"attributes":{"formatter":{"id":"a8d2ce50-1480-46d9-94c4-4caa2ca522d4","type":"BasicTickFormatter"},"plot":{"id":"31772646-56e5-4e1c-a80c-9b2762c35a84","subtype":"Figure","type":"Plot"},"ticker":{"id":"b33ac7dc-ba18-4323-9767-1941a5e9b8c9","type":"BasicTicker"}},"id":"a580bc02-244c-41d5-bb90-80f7f454a3cc","type":"LinearAxis"},{"attributes":{},"id":"b33ac7dc-ba18-4323-9767-1941a5e9b8c9","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"31772646-56e5-4e1c-a80c-9b2762c35a84","subtype":"Figure","type":"Plot"},"ticker":{"id":"b33ac7dc-ba18-4323-9767-1941a5e9b8c9","type":"BasicTicker"}},"id":"ed84778b-9d36-4845-88ad-dee2961bb5fd","type":"Grid"},{"attributes":{"data_source":{"id":"8e20c04f-2d71-4352-a307-c6f31e2306e7","type":"ColumnDataSource"},"glyph":{"id":"4c8c004c-ad84-4b3e-a5bf-5dd606919394","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a9777894-82fe-4267-a403-38ff3330ddf4","type":"Line"},"selection_glyph":null},"id":"ac6287fe-5c28-4461-8d38-9f36ab9f7484","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x ...

# %%
n_points = 20

p_grid = np.linspace(0, 1, n_points)

prior = p_grid >= 0.5

likelihood = np.array([scipy.stats.binom_test(6, 9, p) for p in p_grid])

posterior = likelihood * prior

posterior = posterior / np.sum(posterior)

p = figure(title='grid approximation - prior p_grid >= 0.5', plot_width=400, plot_height=300)
p.line(p_grid, posterior)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="792cfe20-420f-483f-9812-53864c7d6f13"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("792cfe20-420f-483f-9812-53864c7d6f13").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("792cfe20-420f-483f-9812-53864c7d6f13");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '792cfe20-420f-483f-9812-53864c7d6f13' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b39e6e4f-7b65-4a28-abff-c3ac38e9547c":{"roots":{"references":[{"attributes":{"callback":null},"id":"29dde89a-24ca-4025-a774-3d39581a1590","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6eeca283-4bcc-43c9-a804-17183f2505a1","type":"Line"},{"attributes":{"callback":null},"id":"6b54ef59-545e-4772-b007-6e81162c502d","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"35d5f874-3a99-4be9-a090-85995db2e5a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"4
type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA ...

# %%
n_points = 20

p_grid = np.linspace(0, 1, n_points)

prior = np.exp(-5 * np.abs(p_grid - 0.5))

likelihood = np.array([scipy.stats.binom_test(6, 9, p) for p in p_grid])

posterior = likelihood * prior

posterior = posterior / np.sum(posterior)

p = figure(title='grid approximation - prior exp', plot_width=400, plot_height=300)
p.line(p_grid, posterior)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ea22b7a8-7875-46b9-bc95-425047545681"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ea22b7a8-7875-46b9-bc95-425047545681").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ea22b7a8-7875-46b9-bc95-425047545681");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ea22b7a8-7875-46b9-bc95-425047545681' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fcab91a5-370d-47d9-9979-5feb3d4458e3":{"roots":{"references":[{"attributes":{},"id":"b851d484-2ff5-4220-b345-5aad69acf888","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"6938160a-01b4-4922-81cc-665b89c2cfe4","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dc10ce1f-39fa-4e43-b543-27cce974c4fd","type":"PanTool"},{"id":"453c4d56-2526-4e78-b326-c6c5de6ed70f","type":"WheelZoomTool"},{"id":"a324ac6c-33ae-493a-932c-c1651ce24ebc","type":"BoxZoomTool"},{"id":"6938160a-01b4-4922-81cc-665b89c2cfe4","type":"SaveTool"},{"id":"c87fa52b-b797-4144-b403-a01538565ed0","type":"ResetTool"},{"id":"a3003eb5-c342-4945-b2fb-88fbf0752716","type":"HelpTool"}]},"id":"8dfdea3b-04a4-41a0-90d1-eef879d8e573","type":"Toolbar"},{"attributes":{"data_source":{"id":"25b2da9e-2c24-42c8-8259-659fde1506ff","type":"ColumnDataSource"},"glyph":{"id":"86ca9deb-7ddc-43d9-b21d-0c956d8222c4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0f4c8f1a-455b-44ad-9d6b-f9e0f408ae4c","type":"Line"},"selection_glyph":null},"id":"7259bfed-2fab-4edd-9b81-4f7906c4dba6","type":"GlyphRenderer"},{"attributes":{},"id":"0ff1acba-4829-4495-8dbd-73bef0e6652a","type":"ToolEvents"},{"attributes":{"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"c87fa52b-b797-4144-b403-a01538565ed0","type":"ResetTool"},{"attributes":{"overlay":{"id":"b7618940-df29-4606-b277-35422ced6081","type":"BoxAnnotation"},"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"a324ac6c-33ae-493a-932c-c1651ce24ebc","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"eef26f1d-2637-4107-87d5-f2dbf7665251","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b7618940-df29-4606-b277-35422ced6081","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"a3003eb5-c342-4945-b2fb-88fbf0752716","type":"HelpTool"},{"attributes":{"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"453c4d56-2526-4e78-b326-c6c5de6ed70f","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"c94f2f8d-f6e8-4f43-ad6a-f042749c433e","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f4c8f1a-455b-44ad-9d6b-f9e0f408ae4c","type":"Line"},{"attributes":{"plot":null,"text":"grid approximation - prior exp"},"id":"647966d6-c293-460e-ae7a-b3e70b3a1b9c","type":"Title"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86ca9deb-7ddc-43d9-b21d-0c956d8222c4","type":"Line"},{"attributes":{"plot":{"id":"dae25b7d-9f9c-4e26-ac26-bf378bc6a8bf","subtype":"Figure","type":"Plot"}},"id":"dc10ce1f-39fa-4e43-b543-27cce974c4fd","type":"PanTool"},{"attributes":{"below":[{"id":"84d36671-ff86-4ea0-a6a7-a8eaab346987","type":"LinearAxis"}],"left":[{"id":"c70d99ec-8d7f-4a80-8e3e-69ba42cb269f","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"84d36671-ff86-4ea0-a6a7-a8eaab346987","type":"LinearAxis"},{"id":"e1a56746-cce0-42e2-b1ed-0c9ec63b87ab","type":"Grid"},{"id":"c70d99ec-8d7f-4a80-8e3e-69ba42cb269f","type":"LinearAxis"},{"id":"ace5ce23-e9f3-4572-84e1-e52cefb62fb6","type":"Grid"},{"id":"b7618940-df29-4606-b277-35422ced6081","type":"BoxAnnotation"},{"id":"7259bfed-2fab-4edd-9b81-4f7906c4dba6","type":"GlyphRenderer"}],"title":{"id":"647966d6-c293-460e-ae7a-b3e70b3a1b9c","type":"Title"},"tool_events":{"id":"0ff1acba-4829-4495-8dbd-73bef0e66 ...

# %% [markdown]
# # Quadratic Approximation

# %% [markdown]
# # MCMC

# %%
scipy.stats.norm.logpdf

# %%
def mcmc(data, n_samples):
    mu_prior = 0.0
    sigma_prior = 10.0
    mu_current = 10.0
    for i in trange(n_samples):
        mu_candidate = scipy.stats.norm.rvs(mu_current)
        
        log_likelihood_current = scipy.stats.norm(mu_current, 1).logpdf(data).sum()
        log_likelihood_candidate = scipy.stats.norm(mu_candidate, 1).logpdf(data).sum()
        
        log_prior_current = scipy.stats.norm(mu_prior, sigma_prior).logpdf(mu_current)
        log_prior_candidate = scipy.stats.norm(mu_prior, sigma_prior).logpdf(mu_candidate)
        
        log_posterior_current = log_likelihood_current + log_prior_current
        log_posterior_candidate = log_likelihood_candidate + log_prior_candidate
             
        if np.exp(log_posterior_current) > 0:
            ratio = np.exp(log_posterior_candidate) / np.exp(log_posterior_current)
        else:
            ratio = 1.0
        
        #print('ratio:', ratio)
        if np.random.rand() < ratio:
            mu_current = mu_candidate
            
        #print('----------------------')
    return mu_current

# %%
data = scipy.stats.norm.rvs(size=100)
mcmc(data, 10000)
# Out:
# 100%|██████████| 10000/10000 [00:38<00:00, 257.18it/s]
# -0.10522651241919878
